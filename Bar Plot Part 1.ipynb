# %% [markdown]
# # Bar Plot Part 1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
tips_df = sns.load_dataset('tips')

# %%
tips_df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
sns.barplot(x= 'sex', y = 'total_bill',data = tips_df,hue = 'day')
plt.legend()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style='darkgrid')
sns.barplot(x='sex', y='total_bill', hue='day', data=tips_df, errorbar=None)

plt.title("Average Total Bill by Sex and Day")
plt.xlabel("Sex")
plt.ylabel("Average Total Bill")
plt.legend(title='Day')
plt.show()

# %%
sns.barplot(x = tips_df.day, y = tips_df.total_bill,hue = tips_df.day)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x = tips_df.day, y = tips_df.total_bill,hue = tips_df.sex)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data = tips_df,x = 'day', y = 'total_bill',hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
order = ['Sun','Thur','Fri','Sat']
sns.barplot(data = tips_df,x = 'day', y = 'total_bill',hue = 'sex',order=order)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
hue_order = ['Female','Male']
sns.barplot(data = tips_df,x = 'day', y = 'total_bill',hue = 'sex',hue_order=hue_order)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
hue_order = ['Female','Male']
sns.barplot(data = tips_df,y= 'day', x= 'total_bill',hue = 'sex',hue_order=hue_order,orient='h')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
 hue_order = ['Female','Male']
sns.barplot(data = tips_df,x = 'day', y = 'total_bill',hue = 'sex',hue_order=hue_order,palette='hot',saturation=0.3)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
 hue_order = ['Female','Male']
sns.barplot(data = tips_df,x = 'day', y = 'total_bill',hue = 'sex',hue_order=hue_order,palette='hot',saturation=1)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
 hue_order = ['Female','Male']
sns.barplot(data = tips_df,x = 'day', y = 'total_bill',hue = 'sex',hue_order=hue_order,palette='hot',saturation=0.3,errwidth=10,capsize=4)
# Out:
# C:\Users\Shahbaz Junaid\AppData\Local\Temp\ipykernel_6124\1756684601.py:2: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 10}` instead.
#
#   sns.barplot(data = tips_df,x = 'day', y = 'total_bill',hue = 'sex',hue_order=hue_order,palette='hot',saturation=0.3,errwidth=10,capsize=4)
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
 hue_order = ['Female','Male']
sns.barplot(data = tips_df,x = 'day', y = 'total_bill',hue = 'sex',hue_order=hue_order,palette='hot',dodge=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
